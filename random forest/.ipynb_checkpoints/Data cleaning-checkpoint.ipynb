# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv('D:/Desktop/me/IITG/IIT Guwahati sem 6/CS361/archive/Training Data.csv')

# %%
train_df.columns
# Out:
# Index(['Id', 'Income', 'Age', 'Experience', 'Married/Single',
#        'House_Ownership', 'Car_Ownership', 'Profession', 'CITY', 'STATE',
#        'CURRENT_JOB_YRS', 'CURRENT_HOUSE_YRS', 'Risk_Flag'],
#       dtype='object')

# %%
min_value = train_df['Income'].min()
max_value = train_df['Income'].max()
min_value,max_value
# Out:
# (10310, 9999938)

# %%
min_value = train_df['CURRENT_JOB_YRS'].min()
max_value = train_df['CURRENT_JOB_YRS'].max()
min_value,max_value
# Out:
# (0, 14)

# %%
plt.plot(train_df['Income'], train_df['CURRENT_JOB_YRS'], marker='o')  # Plot the data with markers
plt.xlabel('X Axis (10^4 to 10^7)')
plt.ylabel('Y Axis (0 to 14)')
plt.xscale('log')  # Set x-axis to logarithmic scale
plt.ylim(0, 14)     # Set y-axis range from 0 to 14
plt.grid(True)     # Show grid
plt.title('Plot of One Column vs Another')
plt.show()

# %%
plt.plot(train_df['Income'], train_df['CURRENT_JOB_YRS'], marker='o')  # Plot the data with markers
plt.xlabel('X Axis (10^4 to 10^7)')
plt.ylabel('Y Axis (0-5, 5-10, 10-15)')
plt.xscale('log')  # Set x-axis to logarithmic scale
plt.yticks([0, 5, 10], ['0', '5', '10'])  # Set custom ticks and labels for y-axis
plt.ylim(0, 15)     # Set y-axis range from 0 to 14
plt.grid(True)     # Show grid
plt.title('Plot of One Column vs Another')
plt.show()

# %%
# Assuming train_df['Income'] and train_df['CURRENT_JOB_YRS'] are your columns
income_data = train_df['Income']
job_years_data = train_df['CURRENT_JOB_YRS']

# Define the segments based on the conditions you provided
segments = [
    (income_data < 1e5) & (job_years_data < 5),
    (income_data < 1e5) & (job_years_data >= 5) & (job_years_data < 10),
    (income_data < 1e5) & (job_years_data >= 10) & (job_years_data >= 10),
    (income_data >= 1e5) & (income_data < 1e6) & (job_years_data < 5),
    (income_data >= 1e5) & (income_data < 1e6) & (job_years_data >= 5) & (job_years_data < 10),
    (income_data >= 1e5) & (income_data < 1e6) & (job_years_data >= 10),
    (income_data >= 1e6) & (income_data < 1e7) & (job_years_data < 5),
    (income_data >= 1e6) & (income_data < 1e7) & (job_years_data >= 5) & (job_years_data < 10),
    (income_data >= 1e6) & (income_data < 1e7) & (job_years_data >= 10)
]

# Define colors for each segment
colors = ['red', 'blue', 'green', 'orange', 'purple', 'yellow', 'cyan', 'magenta', 'brown']

# Plot each segment with a different color
for seg, color in zip(segments, colors):
    plt.plot(income_data[seg], job_years_data[seg], marker='o', linestyle='', color=color)

plt.xlabel('Income')
plt.ylabel('Current Job Years')
plt.xscale('log')  # Set x-axis to logarithmic scale
plt.yticks([0, 5, 10], ['0', '5', '10'])  # Set custom ticks and labels for y-axis
plt.ylim(0, 15)     # Set y-axis range from 0 to 14
plt.grid(True)     # Show grid
plt.title('Plot of Income vs Current Job Years')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming train_df['Income'], train_df['CURRENT_JOB_YRS'], and train_df['RISK_FLAG'] are your columns
income_data = train_df['Income']
job_years_data = train_df['CURRENT_JOB_YRS']
risk_flag_data = train_df['Risk_Flag']

# Define the segments based on the conditions you provided
segments = [
    (income_data < 1e5) & (job_years_data < 5),
    (income_data < 1e5) & (job_years_data >= 5) & (job_years_data < 10),
    (income_data < 1e5) & (job_years_data >= 10) & (job_years_data >= 10),
    (income_data >= 1e5) & (income_data < 1e6) & (job_years_data < 5),
    (income_data >= 1e5) & (income_data < 1e6) & (job_years_data >= 5) & (job_years_data < 10),
    (income_data >= 1e5) & (income_data < 1e6) & (job_years_data >= 10),
    (income_data >= 1e6) & (income_data < 1e7) & (job_years_data < 5),
    (income_data >= 1e6) & (income_data < 1e7) & (job_years_data >= 5) & (job_years_data < 10),
    (income_data >= 1e6) & (income_data < 1e7) & (job_years_data >= 10)
]

# Define colors for each segment
colors = ['red', 'blue', 'green', 'orange', 'purple', 'yellow', 'cyan', 'magenta', 'brown']

# Define markers for each RISK_FLAG category
markers = ['x', 'o']  # Replaced 'tick' with 'o'

# Plot each segment with a different color and marker based on RISK_FLAG
for seg, color in zip(segments, colors):
    for flag, marker in zip(range(2), markers):  # Iterate over RISK_FLAG categories (0 and 1)
        data = seg & (risk_flag_data == flag)
        if data.any():
            if marker == 'o':  # Change the color for 'o' marker
                plt.plot(income_data[data], job_years_data[data], marker=marker, markersize=2, linestyle='', color='black')
            else:
                plt.plot(income_data[data], job_years_data[data], marker=marker, markersize=2, linestyle='', color=color)
    
    # Print the number of 'x' and 'o' markers in the current block
    num_x = sum((risk_flag_data[seg] == 0) & (income_data[seg] >= 0) & (job_years_data[seg] >= 0))
    num_o = sum((risk_flag_data[seg] == 1) & (income_data[seg] >= 0) & (job_years_data[seg] >= 0))
    print(f"Block: {color}, 'x' count: {num_x}, 'o' count: {num_o}")

plt.xlabel('Income')
plt.ylabel('Current Job Years')
plt.xscale('log')  # Set x-axis to logarithmic scale
plt.yticks([0, 5, 10], ['0', '5', '10'])  # Set custom ticks and labels for y-axis
plt.ylim(0, 15)     # Set y-axis range from 0 to 14
plt.grid(True)     # Show grid
plt.title('Plot of Income vs Current Job Years')
plt.legend()
plt.figure(figsize=(20,12))
plt.show()
# Out:
# Block: red, 'x' count: 623, 'o' count: 136
# Block: blue, 'x' count: 845, 'o' count: 132
# Block: green, 'x' count: 470, 'o' count: 113
# Block: orange, 'x' count: 7017, 'o' count: 1101
# Block: purple, 'x' count: 7924, 'o' count: 1261
# Block: yellow, 'x' count: 4192, 'o' count: 641
# Block: cyan, 'x' count: 71972, 'o' count: 10655
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Block: magenta, 'x' count: 83526, 'o' count: 10825
# Block: brown, 'x' count: 44435, 'o' count: 6132

# %%
import pandas as pd

# Initialize a new DataFrame to store the modified data
new_train_df = train_df.copy()

# Define the segments based on the conditions you provided
segments = [
    (income_data < 1e5) & (job_years_data < 5),
    (income_data < 1e5) & (job_years_data >= 5) & (job_years_data < 10),
    (income_data < 1e5) & (job_years_data >= 10),
    (income_data >= 1e5) & (income_data < 1e6) & (job_years_data < 5),
    (income_data >= 1e5) & (income_data < 1e6) & (job_years_data >= 5) & (job_years_data < 10),
    (income_data >= 1e5) & (income_data < 1e6) & (job_years_data >= 10),
    (income_data >= 1e6) & (income_data < 1e7) & (job_years_data < 5),
    (income_data >= 1e6) & (income_data < 1e7) & (job_years_data >= 5) & (job_years_data < 10),
    (income_data >= 1e6) & (income_data < 1e7) & (job_years_data >= 10)
]

# Define ratios for 'x' to 'o' markers in each region
ratios = [
    (27, 136),  # red
    (40, 132),  # blue
    (50, 1101),  # orange
    (113, 113),  # green
    (800, 1261),  # purple
    (1000, 10655),  # cyan
    (1282, 641),  # yellow
    (21650, 8825),  # magenta
    (12264, 4132)   # brown
]

# Iterate over segments and adjust counts of 'x' and 'o' markers according to ratios
for seg, ratio in zip(segments, ratios):
    num_x, num_o = ratio
    mask_x = (risk_flag_data == 0) & seg
    mask_o = (risk_flag_data == 1) & seg
    indices_x = mask_x[mask_x].sample(n=num_x, replace=True).index
    indices_o = mask_o[mask_o].sample(n=num_o, replace=True).index
    new_train_df.loc[indices_x, 'RISK_FLAG'] = 0
    new_train_df.loc[indices_o, 'RISK_FLAG'] = 1

# Verify the counts of 'x' and 'o' markers in each region
for i, seg in enumerate(segments):
    print(f"Region {i}:")
    print("Count of 'x':", sum((new_train_df['RISK_FLAG'] == 0) & seg))
    print("Count of 'o':", sum((new_train_df['RISK_FLAG'] == 1) & seg))
    print()

# Now, new_train_df contains the modified data with the specified ratios of 'x' to 'o' markers in different regions
new_train_df.shape
# Out:
# Region 0:
# Count of 'x': 27
# Count of 'o': 84
#
# Region 1:
# Count of 'x': 40
# Count of 'o': 84
#
# Region 2:
# Count of 'x': 46
# Count of 'o': 113
#
# Region 3:
# Count of 'x': 113
# Count of 'o': 109
#
# Region 4:
# Count of 'x': 758
# Count of 'o': 796
#
# Region 5:
# Count of 'x': 894
# Count of 'o': 641
#
# Region 6:
# Count of 'x': 1265
# Count of 'o': 629
#
# Region 7:
# Count of 'x': 19065
# Count of 'o': 5995
#
# Region 8:
# Count of 'x': 10732
# Count of 'o': 2978
# (252000, 14)

# %%
new_train_df.shape
# Out:
# (252000, 14)

# %%
import pandas as pd
import numpy as np

# Initialize a new DataFrame to store the modified data
new_train_df = train_df.copy()

# Define the segments based on the conditions you provided
segments = [
    (new_train_df['Income'] < 1e5) & (new_train_df['CURRENT_JOB_YRS'] < 5),
    (new_train_df['Income'] < 1e5) & (new_train_df['CURRENT_JOB_YRS'] >= 5) & (new_train_df['CURRENT_JOB_YRS'] < 10),
    (new_train_df['Income'] < 1e5) & (new_train_df['CURRENT_JOB_YRS'] >= 10),
    (new_train_df['Income'] >= 1e5) & (new_train_df['Income'] < 1e6) & (new_train_df['CURRENT_JOB_YRS'] < 5),
    (new_train_df['Income'] >= 1e5) & (new_train_df['Income'] < 1e6) & (new_train_df['CURRENT_JOB_YRS'] >= 5) & (new_train_df['CURRENT_JOB_YRS'] < 10),
    (new_train_df['Income'] >= 1e5) & (new_train_df['Income'] < 1e6) & (new_train_df['CURRENT_JOB_YRS'] >= 10),
    (new_train_df['Income'] >= 1e6) & (new_train_df['Income'] < 1e7) & (new_train_df['CURRENT_JOB_YRS'] < 5),
    (new_train_df['Income'] >= 1e6) & (new_train_df['Income'] < 1e7) & (new_train_df['CURRENT_JOB_YRS'] >= 5) & (new_train_df['CURRENT_JOB_YRS'] < 10),
    (new_train_df['Income'] >= 1e6) & (new_train_df['Income'] < 1e7) & (new_train_df['CURRENT_JOB_YRS'] >= 10)
]

# Define ratios for 'x' to 'o' markers in each region
ratios = [
    (1, 5),  # red
    (2, 4),  # blue
    (2, 4),  # orange
    (3, 3),  # green
    (3, 3),  # purple
    (3, 3),  # cyan
    (4, 2),  # yellow
    (4, 2),  # magenta
    (5, 1)   # brown
]

# Modify the 'RISK_FLAG' column to contain only the new data with the specified ratios
new_risk_flag_data = np.zeros(len(new_train_df))  # Initialize with zeros
for seg, ratio in zip(segments, ratios):
    num_x, num_o = ratio
    mask_x = seg & (new_risk_flag_data == 0)
    mask_o = seg & (new_risk_flag_data == 1)
    indices_x = np.random.choice(np.where(mask_x)[0], size=num_x, replace=True)
    indices_o = np.random.choice(np.where(mask_o)[0], size=num_o, replace=True)
    new_risk_flag_data[indices_x] = 0
    new_risk_flag_data[indices_o] = 1

new_train_df['RISK_FLAG'] = new_risk_flag_data

# Verify the counts of 'x' and 'o' markers in each region
for i, seg in enumerate(segments):
    print(f"Region {i}:")
    print("Count of 'x':", sum((new_train_df['RISK_FLAG'] == 0) & seg))
    print("Count of 'o':", sum((new_train_df['RISK_FLAG'] == 1) & seg))
    print()

# Now, new_train_df contains only the modified data with the specified ratios of 'x' to 'o' markers in different regions
new_train_df.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [50], in <cell line: 35>()
#      38 mask_o = seg & (new_risk_flag_data == 1)
#      39 indices_x = mask_x[mask_x].sample(n=num_x, replace=True).index
# ---> 40 indices_o = mask_o[mask_o].sample(n=num_o, replace=True).index
#      41 new_risk_flag_data[indices_x] = 0
#      42 new_risk_flag_data[indices_o] = 1
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5446, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5443 if weights is not None:
#    5444     weights = sample.preprocess_weights(self, weights, axis)
# -> 5446 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5447 result = self.take(sampled_indices, axis=axis)
#    5449 if ignore_index:
#
# File ~\anaconda3\lib\site-packages\pandas\core\sample.py:150, in sample(obj_len, size, replace, weights, random_state)
#     147     else:
#     148         raise ValueError("Invalid weights: weights sum to zero")
# --> 150 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     151     np.intp, copy=False
#     152 )
#
# File mtrand.pyx:909, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken
