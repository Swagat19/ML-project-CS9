# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv('D:/Desktop/me/IITG/IIT Guwahati sem 6/CS361/archive/Training Data.csv')

# %%
plt.figure(figsize=(7,7))
train_df['Married/Single'].value_counts().plot(kind='pie',autopct="%.2f%%")
plt.title("Marital Status Ratio")
plt.ylabel("")
plt.show()
train_df['Married/Single'].value_counts()
# Out:
# single     226272
# married     25728
# Name: Married/Single, dtype: int64

# %%
def plotGraph(method, a, b, title=None, **kwargs):
    plt.figure(figsize=(7,7))
    method(data=train_df[[a, b]], **kwargs)
    plt.title(title)
    plt.show()

# %%
plotGraph(sns.histplot, 'Age', 'Married/Single', title="Histogram of Age Groups",element='poly',x='Age',hue='Married/Single')

# %%
plotGraph(sns.histplot, 'Married/Single', 'Income', title="Married/Single and Income", x='Income', hue='Married/Single',element='poly')

# %%
plt.figure(figsize=(20,30))
train_df['Profession'].value_counts().plot(kind='pie',autopct="%.2f%%")
plt.title("Frequency of each profession")
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(20,30))
sns.countplot(y=train_df['Profession'])
plt.title("Frequency of each Profession.")
plt.ylabel("Profession")
plt.xlabel("Count")
plt.show()

# %%
avg_incomes = []
avg_age = []
avg_exp = []

# %%
professions = train_df.groupby('Profession')
professions_list = train_df['Profession'].unique()
professions_list
# Out:
# array(['Mechanical_engineer', 'Software_Developer', 'Technical_writer',
#        'Civil_servant', 'Librarian', 'Economist', 'Flight_attendant',
#        'Architect', 'Designer', 'Physician', 'Financial_Analyst',
#        'Air_traffic_controller', 'Politician', 'Police_officer', 'Artist',
#        'Surveyor', 'Design_Engineer', 'Chemical_engineer',
#        'Hotel_Manager', 'Dentist', 'Comedian', 'Biomedical_Engineer',
#        'Graphic_Designer', 'Computer_hardware_engineer',
#        'Petroleum_Engineer', 'Secretary', 'Computer_operator',
#        'Chartered_Accountant', 'Technician', 'Microbiologist',
#        'Fashion_Designer', 'Aviator', 'Psychologist', 'Magistrate',
#        'Lawyer', 'Firefighter', 'Engineer', 'Official', 'Analyst',
#        'Geologist', 'Drafter', 'Statistician', 'Web_designer',
#        'Consultant', 'Chef', 'Army_officer', 'Surgeon', 'Scientist',
#        'Civil_engineer', 'Industrial_Engineer', 'Technology_specialist'],
#       dtype=object)

# %%
for profession in professions_list:
    p_age_mean = professions.get_group(profession)['Age'].mean()
    p_income_mean = professions.get_group(profession)['Income'].mean()
    p_exp_mean = professions.get_group(profession)['Experience'].mean()
    
    avg_incomes.append(p_income_mean)
    avg_age.append(p_age_mean)
    avg_exp.append(p_exp_mean)

# %%
pdf = pd.DataFrame({
    'Profession':professions_list,
    'Average Age':avg_age,
    'Average Income':avg_incomes,
    'Average Experience':avg_exp
})

pdf.head()
# Out:
#             Profession  Average Age  Average Income  Average Experience
# 0  Mechanical_engineer    49.368986    5.175032e+06            9.526548
# 1   Software_Developer    50.060558    4.891296e+06           10.074807
# 2     Technical_writer    50.406352    4.922266e+06            9.887777
# 3        Civil_servant    52.756175    4.947843e+06            9.993429
# 4            Librarian    47.707433    5.007590e+06            9.091184

# %%
for col in pdf.columns[1:]:
    plt.figure(figsize=(20,20))
    sns.barplot(y=pdf['Profession'], x=pdf[col])
    plt.title(f"{col} of each profession.")
    plt.show()

# %%
plt.figure(figsize=(17,7))
train_df['STATE'].value_counts().plot(kind='barh')
plt.xscale('log')
plt.show()
